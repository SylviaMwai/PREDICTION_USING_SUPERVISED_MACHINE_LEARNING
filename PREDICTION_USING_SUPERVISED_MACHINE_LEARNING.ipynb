# %% [markdown]
# <a href="https://colab.research.google.com/github/SylviaMwai/PREDICTION_USING_SUPERVISED_MACHINE_LEARNING/blob/main/PREDICTION_USING_SUPERVISED_MACHINE_LEARNING.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **1.PROBLEM STATEMENT**

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
df=pd.read_csv("https://raw.githubusercontent.com/AdiPersonalWorks/Random/master/student_scores%20-%20student_scores.csv")
df
# Out:
#     Hours  Scores
# 0     2.5      21
# 1     5.1      47
# 2     3.2      27
# 3     8.5      75
# 4     3.5      30
# 5     1.5      20
# 6     9.2      88
# 7     5.5      60
# 8     8.3      81
# 9     2.7      25
# 10    7.7      85
# 11    5.9      62
# 12    4.5      41
# 13    3.3      42
# 14    1.1      17
# 15    8.9      95
# 16    2.5      30
# 17    1.9      24
# 18    6.1      67
# 19    7.4      69
# 20    2.7      30
# 21    4.8      54
# 22    3.8      35
# 23    6.9      76
# 24    7.8      86

# %% [markdown]
# **2.DATA UNDERSTANDING**

# %%
#previewing first 5 rows of the data
df.head()
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %%
#previewing last 5 rows of the data
df.tail()
# Out:
#     Hours  Scores
# 20    2.7      30
# 21    4.8      54
# 22    3.8      35
# 23    6.9      76
# 24    7.8      86

# %%
#previewing random rows of the data
df.sample()
# Out:
#    Hours  Scores
# 2    3.2      27

# %%
#reviewing 10 rows of the data
df.sample(10)
# Out:
#     Hours  Scores
# 8     8.3      81
# 1     5.1      47
# 6     9.2      88
# 3     8.5      75
# 24    7.8      86
# 14    1.1      17
# 10    7.7      85
# 4     3.5      30
# 5     1.5      20
# 16    2.5      30

# %%
#previewing the columns of the data
df.columns
# Out:
# Index(['Hours', 'Scores'], dtype='object')

# %%
#previewing dimenshion or shape(rows and columns)of the data
df.shape
# Out:
# (25, 2)

# %% [markdown]
# **There are 25rows and 2 columns in the data**

# %%
#previewing information about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Hours   25 non-null     float64
#  1   Scores  25 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 528.0 bytes

# %%
#previewing summary numerical statistics of the data
df.describe()
# Out:
#            Hours     Scores
# count  25.000000  25.000000
# mean    5.012000  51.480000
# std     2.525094  25.286887
# min     1.100000  17.000000
# 25%     2.700000  30.000000
# 50%     4.800000  47.000000
# 75%     7.400000  75.000000
# max     9.200000  95.000000

# %%
#checking for missing values in our data
df.isna().sum()
# Out:
# Hours     0
# Scores    0
# dtype: int64

# %%
#checking for duplicates
df.duplicated().any()
# Out:
# False

# %%
#checking for unique values in our data
df.nunique()
# Out:
# Hours     23
# Scores    23
# dtype: int64

# %% [markdown]
# **3.EXPLORATORY DATA ANALYSIS -- DATA CLEANING/WRANGLING**

# %%
#dropping duplicates
df.drop_duplicates(inplace=True)

# %%
#checking for duplicates
df.duplicated().any()
# Out:
# False

# %% [markdown]
# **4.DATA ANALYSIS AND VISUALIZATION**

# %%
#visualizing the data
df.plot(kind="bar",title="student marks")
plt.show()

# %% [markdown]
# **MODELLING**

# %%
df.head()
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %%
X=df[["Hours"]]
y=df["Scores"]

# %%
#splitting data into train and test set
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=50)

# %%
model= LinearRegression()
#fitting our model to the data
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
prediction=model.predict(X_test)

# %%
from sklearn.metrics import r2_score
print(r2_score(prediction,y_test))
# Out:
# 0.9667389422992672

# %%
import numpy as np
data = np.array(9.25)
data = data.reshape(-1, 1)
score = model.predict(data)
score
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([91.85916415])
